# %% [markdown]
# # Train, Evaluate and Benchmark
#
# Notebook Colab pour:
# - lancer l'entrainement GPU
# - relancer proprement apres interruption avec le meme job_id
# - evaluer le modele
# - benchmarker le checkpoint final contre minimax et mcts

# %%
WORKTREE = '/content/songo-model-stockfish-for-google-collab'
DRIVE_ROOT = '/content/drive/MyDrive/songo-stockfish'
TRAIN_CONFIG = 'config/train.colab_pro.yaml'
EVAL_CONFIG = 'config/evaluation.colab_pro.yaml'
BENCH_CONFIG = 'config/benchmark.colab_pro.yaml'
TRAIN_JOB_ID = 'train_colab_pro_v1'
EVAL_JOB_ID = 'eval_colab_pro_v1'
BENCH_JOB_ID = 'benchmark_colab_pro_v1'

# %%
# !bash -lc "cd $WORKTREE && source .venv/bin/activate && PYTHONPATH=src python -m songo_model_stockfish.cli.main train --config $TRAIN_CONFIG --job-id $TRAIN_JOB_ID"

# %%
# !tail -f {DRIVE_ROOT}/jobs/{TRAIN_JOB_ID}/events.jsonl

# %%
# !bash -lc "cd $WORKTREE && source .venv/bin/activate && PYTHONPATH=src python -m songo_model_stockfish.cli.main evaluate --config $EVAL_CONFIG --job-id $EVAL_JOB_ID"

# %%
# !bash -lc "cd $WORKTREE && source .venv/bin/activate && PYTHONPATH=src python -m songo_model_stockfish.cli.main benchmark --config $BENCH_CONFIG --job-id $BENCH_JOB_ID"
