# %% [markdown]
# # Dataset Generation and Build
#
# Notebook Colab pour:
# - lancer la generation de dataset depuis minimax / mcts
# - suivre le job en direct
# - construire le dataset final train/validation/test

# %%
WORKTREE = '/content/songo-model-stockfish-for-google-collab'
DRIVE_ROOT = '/content/drive/MyDrive/songo-stockfish'
JOB_ID_GENERATE = 'dataset_full_matrix_colab_pro_v1'
JOB_ID_BUILD = 'dataset_build_full_matrix_colab_pro_v1'
GEN_CONFIG = 'config/dataset_generation.full_matrix.colab_pro.yaml'
BUILD_CONFIG = 'config/dataset_build.colab_pro.yaml'

# %%
# !bash -lc "cd $WORKTREE && source .venv/bin/activate && PYTHONPATH=src python -m songo_model_stockfish.cli.main dataset-generate --config $GEN_CONFIG --job-id $JOB_ID_GENERATE"

# %%
# !tail -f {DRIVE_ROOT}/jobs/{JOB_ID_GENERATE}/events.jsonl

# %%
# !bash -lc "cd $WORKTREE && source .venv/bin/activate && PYTHONPATH=src python -m songo_model_stockfish.cli.main dataset-build --config $BUILD_CONFIG --job-id $JOB_ID_BUILD"
